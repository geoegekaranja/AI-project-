# %% [markdown]
# <a href="https://colab.research.google.com/github/geoegekaranja/AI-project-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# User to enter the number of days
days = int(input("Enter the number of days: "))
# Calculate number of seconds in the given days
seconds = days * 24 * 60 * 60
# Display the result
print(f"There are {seconds} seconds in {days} days.")
# Out:
# Enter the number of days: 3
# There are 259200 seconds in 3 days.

# %%
# User to enter radius of a circle
radius = float(input("Enter the radius of the circle: "))
#calculate volume of the circle using radius give
volume = (4/3) * 3.14159 * (radius ** 3)
# Display the result
print(f"The volume of the circle with radius {radius} is {volume:.2f} cubic units.")
# Out:
# Enter the radius of the circle: 7
# The volume of the circle with radius 7.0 is 1436.75 cubic units.

# %%
# Enter length and width of a square
length = float(input("Enter the length of the square: "))
width = float(input("Enter the width of the square: "))
# Calculate and perimeter, area of the square
perimeter = 2 * (length + width)
area = length * width
# Display results
print(f"The perimeter of the square is {perimeter:.2f} units.")
print(f"The area of the square is {area:.2f}2 square units.")
# Out:
# Enter the length of the square: 6
# Enter the width of the square: 6
# The perimeter of the square is 24.00 units.
# The area of the square is 36.00 square units.
